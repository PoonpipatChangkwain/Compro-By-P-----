# %% [markdown]
# # 🎮 OX Game Winner Checker Quiz
#
# **โจทย์:** จงเขียนฟังก์ชัน `check_winner(input_str)` เพื่อตรวจสอบผู้ชนะในเกม OX
#
# **กติกา:**
# 1. **Input:** รับค่าเป็น String (3x3) สามารถรับได้ทั้งตัวอักษรเล็กและใหญ่
# 2. **เงื่อนไขการชนะ:**
#    - ถ้าฝั่ง O ชนะ ให้แสดงผลว่า `"O is a winner"`
#    - ถ้าฝั่ง X ชนะ ให้แสดงผลว่า `"X is a winner"`
#    - ถ้าไม่มีใครชนะ (เสมอ) ให้แสดงผลว่า `"This duel is a draw"`
#    - ถ้ามีตัวอักษรอื่นที่ไม่ใช่ X, O หรือช่องว่าง/ขึ้นบรรทัดใหม่ ให้แสดงผลว่า `"Error please try again"`
#
# **ตัวอย่าง:**
# - Input: `xxx\noox\noox` -> Output: `X is a winner`
# - Input: `oox\noxo\nxxx` -> Output: `X is a winner`
# - Input: `oxo\nxox\nxox` -> Output: `This duel is a draw`

# %%
def check_winner(board_str):
    # เขียนโค้ดของคุณตรงนี้
    pass

# --- ส่วนทดสอบ (Test Cases) ---
test_input = """xxx
oox
oox"""

print(f"Result: {check_winner(test_input)}")

# %%
def omg():
    pass
omg()
# Out:
# oh my god
